# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep=';', encoding= 'latin1')
df.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
regiao_metropolitana = ['Rio de Janeiro','Niterói','São Gonçalo','Duque de Caxias','Nova Iguaçu','Belford Roxo','Magé','Queimados','Itaguaí','Seropédica', 'Paracambi','Guapimirim', 'Tanguá', 'Rio Bonito', 'Silva Jardim', 'Araruama' , 'Cabo Frio', 'Búzios', 'São Pedro da Aldeia','Arraial do Cabo', 'Macaé', 'Casimiro de Abreu','São Jão de Meriti']

# %%
df_metropolitano = df.loc[(df['munic'].isin(regiao_metropolitana)) & (df['ano'] == 2024)]


df_metropolitano.head()
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 33889     1    1  2024  2024m01     5     1  Rio de Janeiro  3304557  Capital
# 33890     4    1  2024  2024m01     5     1  Rio de Janeiro  3304557  Capital
# 33891     5    1  2024  2024m01     5     1  Rio de Janeiro  3304557  Capital
# 33892     6    1  2024  2024m01     4     1  Rio de Janeiro  3304557  Capital
# 33893     7    1  2024  2024m01     5     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 33889           0  ...  16.0   4.0      12                      0
# 33890           0  ...   8.0   6.0      13                      3
# 33891           0  ...  12.0   2.0      46                      3
# 33892           0  ...   2.0   1.0      23                      2
# 33893           0  ...   0.0   0.0      12                      2
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# ...

# %%
df_furto = df_metropolitano.groupby('munic')['furto_celular'].sum().reset_index()
df_furto = df_furto.sort_values(by= 'furto_celular', ascending= False)
df_furto
# Out:
#                   munic  furto_celular
# 15       Rio de Janeiro          29422
# 10              Niterói           1229
# 5       Duque de Caxias            654
# 11          Nova Iguaçu            635
# 18          São Gonçalo            623
# 3             Cabo Frio            261
# 0              Araruama            210
# 7               Itaguaí            189
# 9                  Magé            188
# 2          Belford Roxo            176
# 8                 Macaé             98
# 13            Queimados             67
# 1       Arraial do Cabo             55
# 19  São Pedro da Aldeia             45
# 6            Guapimirim             43
# 17         Silva Jardim             38
# 14           Rio Bonito             36
# 16           Seropédica             34
# 12            Paracambi             31
# 4     Casimiro de Abreu             19
# 20               Tanguá             16

# %%
array_furto_celular = np.array(df_furto['furto_celular'])

# %%
media_furto = np.mean(array_furto_celular)
mediana_furto = np.median(array_furto_celular)
distancia = (media_furto - mediana_furto) / mediana_furto

# %%
print(f'A média é {media_furto}\nA mediana é {mediana_furto}\nA disntância entre eles é de {(distancia * 100):.2f} %')
# Out:
# A média é 1622.3333333333333
# A mediana é 98.0
# A disntância entre eles é de 1555.44 %

# %%
# Intervalo Interquartil (IQR)
#IQR = Q3 - Q1
# Limite Superior = Q3 + (1.5 x IQR)
#Limite Inferior = Q1 - (1.5 X IQR)
#Valores fora desses limites são considerados outliers

q1 = np.percentile(array_furto_celular, 25)
q2 = np.percentile(array_furto_celular, 50)
q3 = np.percentile(array_furto_celular, 75)
iqr = q3-q1
limsup = q3 + (1.5*iqr)
liminf = q1 - (1.5*iqr)

# %%
df_otlsup = df_furto.loc[(df_furto['furto_celular'] >= limsup)]
df_otlsup
# Out:
#               munic  furto_celular
# 15   Rio de Janeiro          29422
# 10          Niterói           1229
# 5   Duque de Caxias            654
# 11      Nova Iguaçu            635
# 18      São Gonçalo            623

# %%
df_otlinf = df_furto.loc[(df_furto['furto_celular'] <= liminf)]
df_otlinf
# Out:
# Empty DataFrame
# Columns: [munic, furto_celular]
# Index: []

# %%
df_otlsup.to_csv('outliers.csv', index=False)
