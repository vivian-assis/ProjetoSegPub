# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/DOMensalEstadoDesde1991.csv', sep= ';')
#df.info()

# %%
df = df.loc[(df['ano']>=2014) & (df['ano'] < 2025)]

# %%
#soma do total por ano
df_rec = df.groupby(['ano'])['recuperacao_veiculos'].sum().reset_index() 
df_rb = df.groupby(['ano'])['roubo_veiculo'].sum().reset_index()
df_f = df.groupby(['ano'])['furto_veiculos'].sum().reset_index()
#renomeando as variáveis

# %%
#transforma dados de ano em string
df_rec['ano']=df_rec['ano'].astype(str)

# %%
#MÉDIA, MEDIANA E DISTÂNIA DA RECUPERAÇÃO DE VEÍCULOS
array_rec = np.array(df_rec['recuperacao_veiculos'])
media_rec = np.mean(array_rec)
mediana_rec = np.median(array_rec)
distancia_rec = (media_rec - mediana_rec)/mediana_rec
print(f"MÉDIA = {media_rec:.2f}\nMEDIANA = {mediana_rec:.2f}\nDISTÂNCIA = {distancia_rec:.2f}")
# Out:
# MÉDIA = 23189.73
# MEDIANA = 23663.00
# DISTÂNCIA = -0.02

# %%
#GRÁFICO DO TOTAL DE RECUPERÇÃO DE VEÍCULOS POR ANO
plt.figure(figsize=(10,5))
plt.plot(df_rec['ano'], df_rec['recuperacao_veiculos'], marker='o', linestyle='-')
plt.title('RECUPERAÇÃO DE VEÍCULOS NA ÚLTIMA DÉCADA\nMÉDIA = 23189.73\nMEDIANA = 23663.00\nDISTÂNCIA = -0.02')
plt.xlabel('Ano')
plt.ylabel('Total de Veículos Recuperados por Ano')
#plt.grid(True) #Não é recomendado utilizar Grids para visualizaçõa de dados
plt.tight_layout()
plt.show()

# %%
#MÉDIA, MEDIANA E DISTÂNIA DO ROUBO DE VEÍCULOS
array_rb = np.array(df_rb['roubo_veiculo'])
media_rb = np.mean(array_rb)
mediana_rb = np.median(array_rb)
distancia = (media_rb - mediana_rb)/mediana_rb
print(f"MÉDIA = {media_rb:.2f}\nMEDIANA = {mediana_rb:.2f}\nDISTÂNCIA = {distancia:.2f}")
# Out:
# MÉDIA = 34520.64
# MEDIANA = 31035.00
# DISTÂNCIA = 0.11

# %%
#GRÁFICO DO TOTAL DE ROUBOS DE VEÍCULOS POR ANO
df_rb['ano']=df_rb['ano'].astype(str)
plt.figure(figsize=(10,5))
plt.plot(df_rb['ano'], df_rb['roubo_veiculo'], marker='o', linestyle='-')
plt.title('ROUBO DE VEÍCULOS NA ÚLTIMA DÉCADA\nMÉDIA = 34520.64\nMEDIANA = 31035.00\nDISTÂNCIA = 0.11')
plt.xlabel('Ano')
plt.ylabel('Total de Veículos Roubados por Ano')
#plt.grid(True) #Não é recomendado utilizar Grids para visualizaçõa de dados
plt.tight_layout()
plt.show()

# %%
#GRÁFICO DISPERSÃO DE ROUBO DE VEÍCULOS POR ANO
plt.figure(figsize=(10,5))
plt.scatter(df_rb['roubo_veiculo'],df_rec['recuperacao_veiculos'])
plt.title('Roubo x Recuperação nos últimos 10 anos')
plt.xlabel('Roubo de Veículos')
plt.ylabel('Recuperação de Veículos furtados')
plt.show()

# %%
#MÉDIA, MEDIANA E DISTÂNIA DO FURTO DE VEÍCULOS
array_f = np.array(df_f['furto_veiculos'])
media_f = np.mean(array_f)
mediana_f = np.median(array_f)
distancia_f = (media_f - mediana_f)/mediana_f
print(f"MÉDIA = {media_f:.2f}\nMEDIANA = {mediana_f:.2f}\nDISTÂNCIA = {distancia_f:.2f}")
# Out:
# MÉDIA = 16053.09
# MEDIANA = 16577.00
# DISTÂNCIA = -0.03

# %%
#GRÁFICO DO TOTAL DE FURTOS DE VEÍCULOS POR ANO
df_f['ano']=df_f['ano'].astype(str)
plt.figure(figsize=(10,5))
plt.plot(df_f['ano'], df_f['furto_veiculos'], marker='o', linestyle='-')
plt.title('FURTO DE VEÍCULOS NA ÚLTIMA DÉCADA\nMÉDIA = 16053.09\nMEDIANA = 16577.00\nDISTÂNCIA = -0.03')
plt.xlabel('Ano')
plt.ylabel('Total de Veículos Furtados por Ano')
#plt.grid(True) #Não é recomendado utilizar Grids para visualizaçõa de dados
plt.tight_layout()
plt.show()

# %%
#GRÁFICO DISPERSÃO DE FURTO DE VEÍCULOS POR ANO
plt.figure(figsize=(10,5))
plt.scatter(df_f['furto_veiculos'],df_rec['recuperacao_veiculos'])
plt.title('Furtos x Recuperação nos últimos 10 anos')
plt.xlabel('Furto de Veículos')
plt.ylabel('Recuperação de Veículos furtados')
plt.show()

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep = ';',  encoding= 'latin1')
#df.info()
df.head(5)
# Out:
#    fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0   3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1   3300159             Aperibé  2014    1  2014m01  Interior           0
# 2   3300209            Araruama  2014    1  2014m01  Interior           2
# 3   3300225               Areal  2014    1  2014m01  Interior           0
# 4   3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
#
#    lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                 0           0    11  ...    8     0      98
# 1                 0           0     0  ...    0     0       0
# 2                 0           0     2  ...    5     0      91
# 3                 0           0     0  ...    0     0       0
# 4                 0           0     2  ...    3     2      46
#
#    pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                     13                 3                0
# 1                      0                 0                0
# 2                     10                 1                0
# 3                      0                 0                0
# 4                      0                 0                0
#
#    pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                          0                      0                   561
# 1                          0                      0                     0
# 2                          0                      0                   480
# 3                          0                      0                     0
# 4                          0                      0                   309
#
#    fase
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
#
# [5 rows x 60 columns]

# %% [markdown]
# # Apreensão de menores

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep = ';',  encoding= 'latin1')
#df.info()
df.head(5)
# Out:
#    fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0   3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1   3300159             Aperibé  2014    1  2014m01  Interior           0
# 2   3300209            Araruama  2014    1  2014m01  Interior           2
# 3   3300225               Areal  2014    1  2014m01  Interior           0
# 4   3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
#
#    lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                 0           0    11  ...    8     0      98
# 1                 0           0     0  ...    0     0       0
# 2                 0           0     2  ...    5     0      91
# 3                 0           0     0  ...    0     0       0
# 4                 0           0     2  ...    3     2      46
#
#    pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                     13                 3                0
# 1                      0                 0                0
# 2                     10                 1                0
# 3                      0                 0                0
# 4                      0                 0                0
#
#    pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                          0                      0                   561
# 1                          0                      0                     0
# 2                          0                      0                   480
# 3                          0                      0                     0
# 4                          0                      0                   309
#
#    fase
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
#
# [5 rows x 60 columns]

# %%
#Identificar os municípios da Baixada que compõem os 25% com mais apreensões.
df_reg = df.loc[(df['regiao'] == 'Baixada Fluminense')]
df_men = df_reg.groupby(['fmun'])['aaapai'].sum().reset_index()
df_men = df_men.sort_values(by = 'aaapai' , ascending=False).reset_index()
df_men
# Out:
#     index                  fmun  aaapai
# 0       1       Duque de Caxias    2971
# 1      12           Nova Iguaçu    2496
# 2      18    São João de Meriti    2039
# 3       0          Belford Roxo    1513
# 4       7                  Magé     802
# 5       8              Mesquita     758
# 6       4               Itaguaí     423
# 7      10             Nilópolis     400
# 8      14             Queimados     364
# 9       5                Japeri     257
# 10     16            Seropédica     192
# 11     13             Paracambi     190
# 12      2            Guapimirim     187
# 13     17  SÃ£o JoÃ£o de Meriti      26
# 14     11          Nova IguaÃ§u      18
# 15      3              ItaguaÃ­      10
# 16      6                 MagÃ©       7
# 17      9            NilÃ³polis       7
# 18     15           SeropÃ©dica       0

# %%
df_array_m = np.array(df_men['aaapai'])

q1 = np.percentile(df_array_m, 25)
q2 = np.percentile(df_array_m, 50)
q3 = np.percentile(df_array_m, 75)
print(f"Q1={q1}\nQ2={q2}\nQ3={q3}")

df_men_q1 = df_men.loc[(df_men['aaapai'] >= q3 )]
# Out:
# Q1=22.0
# Q2=257.0
# Q3=780.0

# %%
#MÉDIA, MEDIANA E DISTÂNIA aaapai

media_men = np.mean(df_array_m)
mediana_men = np.median(df_array_m)
distancia_men = (media_men - mediana_men)/mediana_men
print(f"MÉDIA = {media_men:.2f}\nMEDIANA = {mediana_men:.2f}\nDISTÂNCIA = {distancia_men:.2f}")
# Out:
# MÉDIA = 666.32
# MEDIANA = 257.00
# DISTÂNCIA = 1.59

# %%
df_men_q1.plot(kind='barh' , x= 'fmun', y= 'aaapai')
plt.xlabel('Total Menores Apreendidos')
plt.ylabel('Municípios')
plt.title('Apreensão de Menores na Baixada Fluminense desde 2014')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(df_men['aaapai'],df_men['fmun'])
plt.title('Apreensão de Menores na Baixada Fluminense desde 2014')
plt.xlabel('Total Menores Apreendidos')
plt.ylabel('Municípios')
plt.show()

# %% [markdown]
# # Estelionato

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep = ';',  encoding= 'latin1')
df = df.loc[(df['ano']>=2004) & (df['ano'] < 2025)]
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34007 entries, 1526 to 35532
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        34007 non-null  int64
#  1   mes                         34007 non-null  int64
#  2   ano                         34007 non-null  int64
#  3   mes_ano                     34007 non-null  object
#  4   aisp                        34007 non-null  int64
#  5   risp                        34007 non-null  int64
#  6   munic                       34007 non-null  object
#  7   mcirc                       34007 non-null  int64
#  8   regiao                      34007 non-null  object
#  9   hom_doloso                  34007 non-null  int64
#  10  lesao_corp_morte            34007 non-null  int64
#  11  latrocinio                  34007 non-null  int64
#  12  cvli                        34007 non-null  int64
#  13  hom_por_interv_policial     34007 non-null  int64
#  14  letalidade_violenta         34007 non-null  int64
#  15  tentat_hom                  34007 non-null  int64
#  16  lesao_corp_dolosa           34007 non-null  int64
#  17  estupro                     34007 non-null  int64
#  18  hom_culposo                 34007 non-null  int64
#  19  lesao_corp_culposa          34007 non-null  int64
#  20  roubo_transeunte            34007 non-null  int64
#  21  roubo_celular               34007 non-null  int64
#  22  roubo_em_coletivo           34007 non-null  int64
#  23  roubo_rua                   34007 non-null  int64
#  24  roubo_veiculo               34007 non-null  int64
#  25  roubo_carga                 34007 non-null  int64
#  26  roubo_comercio              34007 non-null  int64
#  27  roubo_residencia            34007 non-null  int64
#  28  roubo_banco                 34007 non-null  int64
#  29  roubo_cx_eletronico         33988 non-null  float64
#  30  roubo_conducao_saque        34007 non-null  int64
#  31  roubo_apos_saque            34007 non-null  int64
#  32  roubo_bicicleta             18144 non-null  float64
#  33  outros_roubos               34007 non-null  int64
#  34  total_roubos                34007 non-null  int64
#  35  furto_veiculos              34007 non-null  int64
#  36  furto_transeunte            34007 non-null  int64
#  37  furto_coletivo              34007 non-null  int64
#  38  furto_celular               34007 non-null  int64
#  39  furto_bicicleta             18144 non-null  float64
#  40  outros_furtos               34007 non-null  int64
#  41  total_furtos                34007 non-null  int64
#  42  sequestro                   34007 non-null  int64
#  43  extorsao                    34007 non-null  int64
#  44  sequestro_relampago         34007 non-null  int64
#  45  estelionato                 34007 non-null  int64
#  46  apreensao_drogas            34007 non-null  int64
#  47  posse_drogas                30887 non-null  float64
#  48  trafico_drogas              30887 non-null  float64
#  49  apreensao_drogas_sem_autor  30887 non-null  float64
#  50  recuperacao_veiculos        34007 non-null  int64
#  51  apf                         30887 non-null  float64
#  52  aaapai                      30887 non-null  float64
#  53  cmp                         30887 non-null  float64
#  54  cmba                        30887 non-null  float64
#  55  ameaca                      34007 non-null  int64
#  56  pessoas_desaparecidas       34007 non-null  int64
#  57  encontro_cadaver            34007 non-null  int64
#  58  encontro_ossada             34007 non-null  int64
#  59  pol_militares_mortos_serv   34007 non-null  int64
#  60  pol_civis_mortos_serv       34007 non-null  int64
#  61  registro_ocorrencias        34007 non-null  int64
#  62  fase                        34007 non-null  int64
# dtypes: float64(10), int64(50), object(3)
# memory usage: 16.6+ MB
#       cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 1526     1    1  2004  2004m01     5     1  Rio de Janeiro  3304557  Capital
# 1527     4    1  2004  2004m01     5     1  Rio de Janeiro  3304557  Capital
# 1528     5    1  2004  2004m01    13     1  Rio de Janeiro  3304557  Capital
# 1529     6    1  2004  2004m01     1     1  Rio de Janeiro  3304557  Capital
# 1530     7    1  2004  2004m01     1     1  Rio de Janeiro  3304557  Capital
#
#       hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 1526           1  ...  NaN   NaN      14                      3
# 1527           1  ...  NaN   NaN      32                      3
# 1528           2  ...  NaN   NaN      64                      4
# 1529           4  ...  NaN   NaN      36                      2
# 1530           2  ...  NaN   NaN      11                      0
#
#       encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 1526                 0                0                          0
# 1527                 1                0                          0
# 1528                 1                0                          0
# 1529                 3                0                          0
# 1530                 3                4                          0
#
#       pol_civis_mortos_serv  registro_ocorrencias  fase
# 1526                      0                   637     3
# 1527                      0                   447     3
# 1528                      0                   699     3
# 1529                      0                   455     3
# 1530                      0                   143     3
#
# [5 rows x 63 columns]

# %%
#Analisar a evolução dos registros de estelionato na cidade do Rio de Janeiro.
df_RJ = df.loc[(df['munic'] == 'Rio de Janeiro')]
df_RJ = df.loc[(df['munic'] == 'Rio de Janeiro')]
df_estl = df_RJ.groupby(['ano'])['estelionato'].sum().reset_index()
df_estl = df_estl.sort_values(by = 'ano').reset_index()
df_estl
# Out:
#     index   ano  estelionato
# 0       0  2004         7727
# 1       1  2005         9101
# 2       2  2006        11020
# 3       3  2007        13319
# 4       4  2008        13589
# 5       5  2009        12520
# 6       6  2010        14292
# 7       7  2011        17574
# 8       8  2012        19589
# 9       9  2013        21093
# 10     10  2014        20151
# 11     11  2015        20287
# 12     12  2016        21707
# 13     13  2017        17305
# 14     14  2018        20073
# 15     15  2019        23648
# 16     16  2020        28463
# 17     17  2021        40364
# 18     18  2022        66354
# 19     19  2023        62829
# 20     20  2024        75518

# %%
df_estl['ano']=df_estl['ano'].astype(str)

# %%
df_array_estl = np.array(df_estl['estelionato'])
media_estl = np.mean(df_array_estl)
mediana_estl = np.median(df_array_estl)
distancia_estl = (media_estl - mediana_estl)/mediana_estl
print(f"MÉDIA = {media_estl:.2f}\nMEDIANA = {mediana_estl:.2f}\nDISTÂNCIA = {distancia:.2f}")
# Out:
# MÉDIA = 25548.71
# MEDIANA = 20073.00
# DISTÂNCIA = 0.11

# %%
plt.figure(figsize=(10,5))
plt.plot(df_estl['ano'], df_estl['estelionato'], marker='o', linestyle='-')
plt.title('Evolução dos Registros de Estelionato na Cidade do Rio de Janeiro (2004-2024)\nMÉDIA = 24999.43\nMEDIANA = 20073.00\nDISTÂNCIA = 0.25')
plt.xlabel('Ano')
plt.ylabel('Estelionato')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df_estl.plot(kind='bar' , x= 'ano', y= 'estelionato')
plt.title('Evolução dos Registros de Estelionato na Cidade do Rio de Janeiro (2004-2024)\nMÉDIA = 24999.43\nMEDIANA = 20073.00\nDISTÂNCIA = 0.25')
plt.xlabel('Ano')
plt.ylabel('Estelionato')
plt.tight_layout()
plt.show()

# %%
df_dlg = df_RJ.groupby(['cisp'])['estelionato'].sum().reset_index()
df_dlg = df_dlg.sort_values(by = 'estelionato').reset_index()
df_dlg
# Out:
#     index  cisp  estelionato
# 0      41    45           98
# 1       7    11         1144
# 2       4     7         1877
# 3      39    43         5125
# 4      40    44         5756
# 5      27    31         5859
# 6      36    40         5939
# 7      13    17         6130
# 8       1     4         6552
# 9      21    25         6588
# 10      3     6         6771
# 11     35    39         6965
# 12     22    26         7364
# 13     20    24         7565
# 14     26    30         7883
# 15     34    38         9173
# 16     11    15         9210
# 17     14    18         9362
# 18     24    28         9539
# 19      9    13        10581
# 20     37    41        11419
# 21     16    20        12155
# 22     23    27        12323
# 23     18    22        12347
# 24     19    23        13277
# 25     32    36        13319
# 26     29    33        14064
# 27     33    37        14234
# 28      5     9        15577
# 29     17    21        16160
# 30     25    29        16191
# 31     10    14        16787
# 32     38    42        16807
# 33      6    10        17822
# 34     15    19        18689
# 35      8    12        19019
# 36      2     5        19720
# 37     30    34        21153
# 38      0     1        25531
# 39     28    32        28267
# 40     31    35        35210
# 41     12    16        36971

# %%
df_array_del = np.array(df_dlg['estelionato'])

q1 = np.percentile(df_dlg, 25)
q2 = np.percentile(df_dlg, 50)
q3 = np.percentile(df_dlg, 75)
print(f"Q1={q1}\nQ2={q2}\nQ3={q3}")
df_dlg_q3 = df_dlg.loc[(df_dlg['estelionato'] >= q3 )]
# Out:
# Q1=17.25
# Q2=33.0
# Q3=6725.25

# %%
df_dlg_q3.tail(20).plot(kind='bar' , x= 'cisp', y= 'estelionato')
plt.xlabel('Delegacias por jurisdição')
plt.ylabel('Ocorrências')
plt.title('Delegacias que compõem 25% com mais ocorrências')
plt.show()

# %%
df_dlg_q3.head(10).plot(kind='bar' , x= 'cisp', y= 'estelionato')
plt.xlabel('Delegacia')
plt.ylabel('Ocorrências')
plt.title('Delegacias que compõem 25% com mais ocorrências')
plt.show()
